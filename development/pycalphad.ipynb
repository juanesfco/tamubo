# %%
from pycalphad import Workspace, variables as v
from pycalphad.property_framework.metaproperties import IsolatedPhase
import matplotlib.pyplot as plt

wks2 = Workspace('alzn_mey.tdb', ['AL', 'ZN'],
                ['FCC_A1', 'HCP_A3', 'LIQUID'],
                {v.X('ZN'):(0,1,0.02), v.T: 600, v.P:101325, v.N: 1})

fig = plt.figure()
ax = fig.add_subplot()

x = wks2.get(v.X('ZN'))
ax.set_xlabel(f"{v.X('ZN').display_name} [{v.X('ZN').display_units}]")

for phase_name in wks2.phases:
    # Workaround for poor starting point selection in IsolatedPhase
    metastable_wks = wks2.copy()
    metastable_wks.phases = [phase_name]
    prop = IsolatedPhase(phase_name, metastable_wks)(f'GM({phase_name})')
    prop.display_name = f'GM({phase_name})'
    ax.plot(x, wks2.get(prop), label=prop.display_name)
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 from pycalphad.property_framework.metaproperties import IsolatedPhase
#       3 import matplotlib.pyplot as plt
# ----> 5 wks2 = Workspace('alzn_mey.tdb', ['AL', 'ZN'],
#       6                 ['FCC_A1', 'HCP_A3', 'LIQUID'],
#       7                 {v.X('ZN'):(0,1,0.02), v.T: 600, v.P:101325, v.N: 1})
#       9 fig = plt.figure()
#      10 ax = fig.add_subplot()
#
# File ~/tamubo/venvs/venv313/lib/python3.13/site-packages/pycalphad/core/workspace.py:329, in Workspace.__init__(self, *args, **kwargs)
#     327 for kwarg_name in init_order:
#     328     if kwarg_name in kwargs.keys():
# --> 329         setattr(self, kwarg_name, kwargs[kwarg_name])
#     330     else:
#     331         # trigger default constructor (which is allowed to fail)
#     332         getattr(self, kwarg_name)
#
# File ~/tamubo/venvs/venv313/lib/python3.13/site-packages/pycalphad/core/workspace.py:114, in TypedField.__set__(self, obj, value)
#     112 "Sets the value of the attribute in an object, handling type coercion via the `cast_from` method if the direct assignment isn't possible. It raises `TypeError` if coercion fails."
#     113 if (self.type != NoneType) and not isa(value, self.type) and value is not None:
# --> 114     value = self.type.cast_from(value)
#     115 elif value is None and self.default_factory is not None:
#     116     value = self.default_factory(obj)
#
# File ~/tamubo/venvs/venv313/lib/python3.13/site-packages/pycalphad/io/database.py:124, in Database.cast_from(cls, val)
#     122 @classmethod
#     123 def cast_from(cls, val):
# --> 124     return cls(val)
#
# File ~/tamubo/venvs/venv313/lib/python3.13/site-packages/pycalphad/io/database.py:115, in Database.__new__(cls, *args)
#     112     return cls.from_file(fname, fmt=fmt)
#     113 elif fname.find('\n') == -1:
#     114     # Single-line string; it's probably a filename
# --> 115     return cls.from_file(fname, fmt=fmt)
#     116 else:
#     117     # Newlines found: probably a full database string
#     118     return cls.from_string(fname, fmt=fmt)
#
# File ~/tamubo/venvs/venv313/lib/python3.13/site-packages/pycalphad/io/database.py:221, in Database.from_file(fname, fmt)
#     218 else:
#     219     # It's not file-like, so it's probably a filename
#     220     need_to_close = True
# --> 221     fd = open(fname, mode='r')
#     222 try:
#     223     dbf = Database()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'alzn_mey.tdb'
