# %% [markdown]
# # In this notebook we are going to see how tensorflow does in solving a regression problem using a gaussian process

# %% [markdown]
# ## 0. Imports

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.13.1
# GPUs: []
